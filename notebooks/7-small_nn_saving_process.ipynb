# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy
# Out:
# 2025-10-19 23:07:48.964432: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-19 23:07:49.536878: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-19 23:07:50.968858: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
def f(x:float, y:float) -> float:
    return np.cos(x+y) + np.sin(x*y) - np.exp((x*x)/50) + 1.5

# %%
def binary_f(x:float, y:float) -> float:
    value = f(x, y)
    return np.where(value < 0.0, 0, 1)

# %%
rng = np.random.default_rng(12345)
x_random = (10 - (-10)) * rng.random((2_500,)) + (-10)
y_random = (10 - (-10)) * rng.random((2_500,)) + (-10)
z_random = binary_f(x_random, y_random)

# %%
training_X = np.stack((x_random, y_random), axis=-1)
training_Y = z_random

# %%
model = Sequential([
    Dense(units=2, activation='elu'),
    Dense(units=500, activation='elu'),
    Dense(units=1200, activation='elu'),
    Dense(units=1200, activation='elu'),
    Dense(units=500, activation='elu'),
    Dense(units=1, activation='linear')
])
model.compile(
    optimizer='adam',
    loss=BinaryCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.BinaryAccurac()]
)
